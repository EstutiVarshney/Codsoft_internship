# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# Reading file and loading the data in df and printing top 5 rows
df = pd.read_csv("C:\\Users\\dell\\Downloads\\IRIS.csv")
df.head()
# Out:
#    ID  sepal_length  sepal_width  petal_length  petal_width      species
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# total number of rows and column
df.shape
# Out:
# (150, 6)

# %%
#getting information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            150 non-null    int64
#  1   sepal_length  150 non-null    float64
#  2   sepal_width   150 non-null    float64
#  3   petal_length  150 non-null    float64
#  4   petal_width   150 non-null    float64
#  5   species       150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# to check the no. of missing values in each cols.
df.isnull().sum()
# Out:
# ID              0
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#describe the dataset
df.describe()
# Out:
#                ID  sepal_length  sepal_width  petal_length  petal_width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.054000      3.758667     1.198667
# std     43.445368      0.828066     0.433594      1.764420     0.763161
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %%
#Visualize the data with seaborn
sns.pairplot(df,hue="species")
plt.show()

# %%
#Plotting the sepal length and width
df.plot(kind="scatter",x= "sepal_length", y="sepal_width")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
#Checking the total number of species
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
#Checking the count by plot
sns.countplot(x='species', data=df)
plt.show()

# %%
x=df.drop("species", axis=1)
x.head()
# Out:
#    ID  sepal_length  sepal_width  petal_length  petal_width
# 0   1           5.1          3.5           1.4          0.2
# 1   2           4.9          3.0           1.4          0.2
# 2   3           4.7          3.2           1.3          0.2
# 3   4           4.6          3.1           1.5          0.2
# 4   5           5.0          3.6           1.4          0.2

# %%
y=df["species"]
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: species, dtype: object

# %%
#Data Analysis

# %%
#Split data into train and test tests
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
x_train.shape
# Out:
# (120, 5)

# %%
x_test.shape
# Out:
# (30, 5)

# %%
y_train.shape
# Out:
# (120,)

# %%
y_test.shape
# Out:
# (30,)

# %%
#select the algorithm
from sklearn.linear_model import LogisticRegression

# %%
#Instantiate and fit the model
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#Checking the accuracy score of model
lr.score(x_test, y_test)
# Out:
# 1.0

# %%
#Predict the model
y_pred=lr.predict(x_test)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
#compare the actual and predicted output
df2=pd.DataFrame({
    "Actual":y_test,
    "Predicted":y_pred
})
df2
# Out:
#               Actual        Predicted
# 114   Iris-virginica   Iris-virginica
# 62   Iris-versicolor  Iris-versicolor
# 33       Iris-setosa      Iris-setosa
# 107   Iris-virginica   Iris-virginica
# 7        Iris-setosa      Iris-setosa
# 100   Iris-virginica   Iris-virginica
# 40       Iris-setosa      Iris-setosa
# 86   Iris-versicolor  Iris-versicolor
# 76   Iris-versicolor  Iris-versicolor
# 71   Iris-versicolor  Iris-versicolor
# 134   Iris-virginica   Iris-virginica
# 51   Iris-versicolor  Iris-versicolor
# 73   Iris-versicolor  Iris-versicolor
# 54   Iris-versicolor  Iris-versicolor
# 63   Iris-versicolor  Iris-versicolor
# 37       Iris-setosa      Iris-setosa
# 78   Iris-versicolor  Iris-versicolor
# 90   Iris-versicolor  Iris-versicolor
# 45       Iris-setosa      Iris-setosa
# 16       Iris-setosa      Iris-setosa
# 121   Iris-virginica   Iris-virginica
# 66   Iris-versicolor  Iris-versicolor
# 24       Iris-setosa      Iris-setosa
# 8        Iris-setosa      Iris-setosa
# ...

# %%
#Check the accuracy score
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]], dtype=int64)

# %%
lr.coef_
# Out:
# array([[-0.11647509,  1.05041787,  0.59332564, -1.26545064, -0.65291665],
#        [-0.05713472, -0.40005695, -0.43566422,  0.96400254, -0.97640414],
#        [ 0.17360981, -0.65036092, -0.15766141,  0.3014481 ,  1.6293208 ]])

# %%
lr.intercept_
# Out:
# array([  6.33184233,   8.54832842, -14.88017076])

# %%
import math
def sigmoid(x):
    return 1/ (1+ math.exp(-x))

# %%
def prediction_function(sepal_length):
    z=0.84996928 * sepal_length + 9.27663407
    y=sigmoid(z)
    return y

# %%
sepal_length=5
prediction_function(sepal_length)
# Out:
# 0.9999986648698833
